# %%
#define a function to add the elements present in a tuple.tuple will be given as an argument
def new(tup1):
    new=0
    for i in tup1:
        new=new+i
    print(new)   
tup=(1,2,3,4)
new(tup)
# Out:
# 10

# %%
#using zip function make a list of tupples and then write a program to sort a list of tuples using lambda.
l1=[24,56,63,90]
l2=[85,12,89,12]
m=(list(zip(l1,l2)))
m.sort(key = lambda x: x[1])
print("According to second element")
print(m)
print("According to first element")
m.sort()
print(m)
# Out:
# According to second element
# [(56, 12), (90, 12), (24, 85), (63, 89)]
# According to first element
# [(24, 85), (56, 12), (63, 89), (90, 12)]

# %%
#open and write to a file that is not writable
f=open("file1.txt")
try :
    f.write(" hellooo")
except:
    f.write(" file is not writable")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ffec6c556be7> in <module>
#       1 #open and write to a file that is not writable
# ----> 2 f=open("file1.txt")
#       3 try :
#       4     f.write(" hellooo")
#       5 except:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.txt'

# %%
f=open('file1.txt')
try:
    f.write("Hello Saumya")
except:
    print("Error")
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a02e907a45ee> in <module>
# ----> 1 f=open('file1.txt')
#       2 try:
#       3     f.write("Hello Saumya")
#       4 except:
#       5     print("Error")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.txt'

# %%
import pandas as pd
import numpy as np

# crete a sample dataframe
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', np.NAN, 'yellow', np.NAN, 'black', 'green', 'red']
})

# view the data
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data.loc[(data.age >= 20), ['section', 'city']] = ['S','Pune']
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       S     Pune      F             NaN
# 2   13       C   Mumbai      F          yellow
# 3   21       S     Pune      M             NaN
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %% [markdown]
# By importing required module create a dataframe.Display the dataframe {'Brand' : ['Maruti', 'Hyundai', 'Tata', 'Mahindra',
# 'Maruti', 'Hyundai', 'Renault', 'Tata', 'Maruti'], 'Year' : [2012, 2014, 2011, 2015, 2012,
# 2016, 2014, 2018, 2019], 'Kms Driven' : [50000, 30000, 60000,
# 25000, 10000, 46000,
# 31000, 15000, 12000], 'City' : ['Gurgaon', 'Delhi', 'Mumbai',
# 'Delhi', 'Mumbai', 'Delhi',
# 'Mumbai','Chennai', 'Ghaziabad'], 'Mileage' : [28, 27, 25, 26, 28,
# 29, 24, 21, 24]}
#
# After creating perform the following set of questions:-
# 1.selecting cars with brand 'Maruti' and Mileage > 25
# 2.selecting range of rows from 2 to 5
# 3.updating values of Mileage if Year < 2015
# 4.selecting 0th, 2th, 4th, and 7th index rows
# 5.selecting rows from 1 to 4 and columns from 2 to 4

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({
     'Brand' : ['Maruti', 'Hyundai', 'Tata', 'Mahindra','Maruti', 'Hyundai', 'Renault', 'Tata', 'Maruti'],
     'Year' : [2012, 2014, 2011, 2015, 2012,2016, 2014, 2018, 2019],
     'Kms Driven' : [50000, 30000, 60000,25000, 10000, 46000,31000, 15000, 12000],
     'City' : ['Gurgaon', 'Delhi', 'Mumbai','Delhi', 'Mumbai', 'Delhi','Mumbai','Chennai', 'Ghaziabad'],
     'Mileage' : [28, 27, 25, 26, 28,29, 24, 21, 24]})
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
#1.selecting cars with brand 'Maruti' and Mileage > 25
data.loc[(data.Mileage>25) & (data.Brand=='Maruti')]
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
#2.selecting range of rows from 2 to 5
data.loc[2:5]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
#3.updating values of Mileage if Year < 2015
data.loc[(data.Year<2015),('Mileage')]= '23'
data
# Out:
#       Brand  Year  Kms Driven       City Mileage
# 0    Maruti  2012       50000    Gurgaon      23
# 1   Hyundai  2014       30000      Delhi      23
# 2      Tata  2011       60000     Mumbai      23
# 3  Mahindra  2015       25000      Delhi      26
# 4    Maruti  2012       10000     Mumbai      23
# 5   Hyundai  2016       46000      Delhi      29
# 6   Renault  2014       31000     Mumbai      23
# 7      Tata  2018       15000    Chennai      21
# 8    Maruti  2019       12000  Ghaziabad      24

# %%
#4.selecting 0th, 2th, 4th, and 7th index rows
data.loc[[0,2,4,7]]
# Out:
#     Brand  Year  Kms Driven     City Mileage
# 0  Maruti  2012       50000  Gurgaon      23
# 2    Tata  2011       60000   Mumbai      23
# 4  Maruti  2012       10000   Mumbai      23
# 7    Tata  2018       15000  Chennai      21

# %%
#5.selecting rows from 1 to 4 and columns from 2 to 4
data.iloc[1:5,2:4]
# Out:
#    Kms Driven    City
# 1       30000   Delhi
# 2       60000  Mumbai
# 3       25000   Delhi
# 4       10000  Mumbai

# %% [markdown]
# -By importing required module create a dataframe.Display the dataframe {'age':[30, 2, 12, 4, 32, 33, 69],
#                                                                         'color':['blue', 'green', 'red', 'white', 'gray','black', 'red']
#                                                                         'food':['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans']
#                                                                         'height':[165, 70, 120, 80, 180, 172, 150]
#                                                                         'score':[4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2]
#                                                                         'state':['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX'] }
#                                                                         index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia']
#
#
# **After creating perform the following set of questions:-
# 1.selecting column penelope
# 2.selecting columns cornelia,jane,dean
# 3.selecting columns from aaron upto dean
# 4.selecting 4th index column
# 5.selecting rows from 1 to 4 and 2nd column

# %%
d = pd.DataFrame({'age':[30, 2, 12, 4, 32, 33, 69], 
                   'color':['blue', 'green', 'red', 'white', 'gray','black', 'red'],
                   'food':['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans'],
                   'height':[165, 70, 120, 80, 180, 172, 150],
                   'score':[4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2],
                   'state':['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX']
                   },
                    index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'])
d
# Out:
#            age  color    food  height  score state
# Jane        30   blue   Steak     165    4.6    NY
# Nick         2  green    Lamb      70    8.3    TX
# Aaron       12    red   Mango     120    9.0    FL
# Penelope     4  white   Apple      80    3.3    AL
# Dean        32   gray  Cheese     180    1.8    AK
# Christina   33  black   Melon     172    9.5    TX
# Cornelia    69    red   Beans     150    2.2    TX

# %%
#1.selecting column penelope
d.loc[['Penelope']]
# Out:
#           age  color   food  height  score state
# Penelope    4  white  Apple      80    3.3    AL

# %%
#2.selecting columns cornelia,jane,dean 
d.loc[['Cornelia','Jane','Dean']]
# Out:
#           age color    food  height  score state
# Cornelia   69   red   Beans     150    2.2    TX
# Jane       30  blue   Steak     165    4.6    NY
# Dean       32  gray  Cheese     180    1.8    AK

# %%
#3.selecting columns from aaron upto dean 
d.iloc[2:5]
# Out:
#           age  color    food  height  score state
# Aaron      12    red   Mango     120    9.0    FL
# Penelope    4  white   Apple      80    3.3    AL
# Dean       32   gray  Cheese     180    1.8    AK

# %%
#4.selecting 4th index column
d.iloc[0:7,4:5]
# Out:
#            score
# Jane         4.6
# Nick         8.3
# Aaron        9.0
# Penelope     3.3
# Dean         1.8
# Christina    9.5
# Cornelia     2.2

# %%
#5.selecting rows from 1 to 4 and 2nd column
d.iloc[0:4,1:2]
# Out:
#           color
# Jane       blue
# Nick      green
# Aaron       red
# Penelope  white
